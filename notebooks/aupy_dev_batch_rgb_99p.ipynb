# %% [markdown]
# A notebook for batch processing the Ries Crater field trip dataset into RGB products, using the fully automated 99th percentile stretch routine.

# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg' # note - requires Inkscape to be installed, and to be accessible from the terminal
# on macos, add inkscape to the path with `sudo ln -s /Applications/Inkscape.app/Contents/MacOS/inkscape /usr/local/bin/inkscape`
# %matplotlib inline

# %%
import aupy

# %%
from pathlib import Path

# %%
data_dir = Path('..','..', 'data')
# check that the data directory exists
if not data_dir.exists():
    raise FileNotFoundError(f"Data directory {data_dir} does not exist.")

# %%
# make a list of all the directories in the data directory
sols = [d.name for d in data_dir.iterdir()]
sols.sort()

# %%
sols
# Out:
# ['SOL1', 'SOL2', 'SOL3', 'SOL4', 'SOL5', 'SOL6', 'TEAM_RGB', 'sol99_4']

# %% [markdown]
# The batch script

# %%
for sol in sols:
    # get the scenes in the sol directory
    sol_dir = data_dir / sol
    # check that the sol directory exists
    if not sol_dir.exists():
        raise FileNotFoundError(f"Sol directory {sol_dir} does not exist.")
    # get the scenes in the sol directory
    scenes = [d.name for d in sol_dir.iterdir() if d.is_dir()]
    scenes.sort()
    
    print(f'{sol}: {scenes}')
    for scene in scenes:

        # look for subdirectorys in the scene directory
        scene_dir = sol_dir / scene
        # check that the scene directory exists
        if not scene_dir.exists():
            raise FileNotFoundError(f"Scene directory {scene_dir} does not exist.")
        # get the subdirectories in the scene directory
        trials = [d.name for d in scene_dir.iterdir() if d.is_dir()]
        trials.sort()

        if trials == []:
            trials = [None]

        print(f'  {sol} {scene}: {trials}')        
        for trial in trials:
            print(f'    {sol} {scene} {trial}')

            # process HRC
            hrc_loader = aupy.AupeIO('HRC', 'RGB', sol, scene, trial=trial)
            if hrc_loader.input_files != []:            
                hrc_rgb = hrc_loader.load_frame()
                hrc_rgb.debayer()
                hrc_rgb.export_image('99p')
                hrc_rgb.export_image('bps')

            # process LWAC
            lwac_loader = aupy.AupeIO('LWAC', 'RGB', sol, scene, trial=trial)
            if lwac_loader.input_files != []:
                lwac_rgb = lwac_loader.load_frame()                        
                lwac_rgb.export_image('99p')
                lwac_rgb.export_image('bps')

            # process RWAC
            rwac_loader = aupy.AupeIO('RWAC', 'RGB', sol, scene, trial=trial)
            if rwac_loader.input_files != []:
                rwac_rgb = rwac_loader.load_frame()            
                rwac_rgb.export_image('99p')
                rwac_rgb.export_image('bps')
# Out:
# SOL1: ['sol1_0', 'sol1_1', 'sol1_2', 'sol1_3', 'sol1_4', 'sol1_5']
#   SOL1 sol1_0: [None]
#     SOL1 sol1_0 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL1 sol1_1: [None]
#     SOL1 sol1_1 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL1 sol1_2: [None]
#     SOL1 sol1_2 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL1 sol1_3: [None]
#     SOL1 sol1_3 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL1 sol1_4: [None]
#     SOL1 sol1_4 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL1 sol1_5: [None]
#     SOL1 sol1_5 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# SOL2: ['sol2_0', 'sol2_1', 'sol2_10', 'sol2_11', 'sol2_12', 'sol2_13', 'sol2_14', 'sol2_15', 'sol2_16', 'sol2_17', 'sol2_18', 'sol2_19', 'sol2_2', 'sol2_20', 'sol2_21', 'sol2_22', 'sol2_23', 'sol2_3', 'sol2_4', 'sol2_5', 'sol2_6', 'sol2_7', 'sol2_8', 'sol2_9']
#   SOL2 sol2_0: [None]
#     SOL2 sol2_0 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_1: [None]
#     SOL2 sol2_1 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_10: [None]
#     SOL2 sol2_10 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_11: [None]
#     SOL2 sol2_11 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_12: [None]
#     SOL2 sol2_12 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_13: [None]
#     SOL2 sol2_13 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_14: [None]
#     SOL2 sol2_14 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_15: ['Trial1', 'Trial2']
#     SOL2 sol2_15 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL2 sol2_15 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_16: [None]
#     SOL2 sol2_16 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_17: [None]
#     SOL2 sol2_17 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_18: [None]
#     SOL2 sol2_18 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_19: [None]
#     SOL2 sol2_19 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_2: [None]
#     SOL2 sol2_2 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_20: [None]
#     SOL2 sol2_20 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_21: [None]
#     SOL2 sol2_21 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_22: [None]
#     SOL2 sol2_22 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_23: [None]
#     SOL2 sol2_23 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_3: [None]
#     SOL2 sol2_3 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_4: [None]
#     SOL2 sol2_4 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_5: [None]
#     SOL2 sol2_5 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_6: [None]
#     SOL2 sol2_6 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_7: [None]
#     SOL2 sol2_7 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_8: [None]
#     SOL2 sol2_8 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL2 sol2_9: [None]
#     SOL2 sol2_9 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# SOL3: ['sol3_0', 'sol3_1', 'sol3_2', 'sol3_3', 'sol3_4', 'sol3_5', 'sol3_6', 'sol3_7', 'sol3_8', 'sol3_9']
#   SOL3 sol3_0: ['Frame1', 'Frame2', 'Frame3', 'Frame4']
#     SOL3 sol3_0 Frame1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_0 Frame2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_0 Frame3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_0 Frame4
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_1: ['Frame1', 'Frame2', 'Frame3']
#     SOL3 sol3_1 Frame1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_1 Frame2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_1 Frame3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_2: ['Frame1', 'Frame2', 'Frame3']
#     SOL3 sol3_2 Frame1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_2 Frame2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_2 Frame3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_3: [None]
#     SOL3 sol3_3 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_4: [None]
#     SOL3 sol3_4 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_5: ['Frame1', 'Frame2']
#     SOL3 sol3_5 Frame1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_5 Frame2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_6: [None]
#     SOL3 sol3_6 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_7: [None]
#     SOL3 sol3_7 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_8: [None]
#     SOL3 sol3_8 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL3 sol3_9: ['Trial_1', 'Trial_2']
#     SOL3 sol3_9 Trial_1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL3 sol3_9 Trial_2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# SOL4: ['sol4_0', 'sol4_1', 'sol4_2', 'sol4_3', 'sol4_4', 'sol4_5']
#   SOL4 sol4_0: ['Trial1', 'Trial2']
#     SOL4 sol4_0 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL4 sol4_0 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL4 sol4_1: [None]
#     SOL4 sol4_1 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL4 sol4_2: [None]
#     SOL4 sol4_2 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL4 sol4_3: [None]
#     SOL4 sol4_3 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL4 sol4_4: ['Trial1', 'Trial2', 'Trial3']
#     SOL4 sol4_4 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL4 sol4_4 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL4 sol4_4 Trial3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL4 sol4_5: ['Trial1', 'Trial2', 'Trial3']
#     SOL4 sol4_5 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL4 sol4_5 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL4 sol4_5 Trial3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# SOL5: ['sol5_0', 'sol5_1', 'sol5_2', 'sol5_3', 'sol5_4', 'sol5_5', 'sol5_6', 'sol5_7', 'sol5_8']
#   SOL5 sol5_0: ['Trail4', 'Trial1', 'Trial2', 'Trial3']
#     SOL5 sol5_0 Trail4
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_0 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_0 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_0 Trial3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_1: ['Trail1']
#     SOL5 sol5_1 Trail1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_2: ['Trial1', 'Trial2']
#     SOL5 sol5_2 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_2 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_3: ['Trial1', 'Trial2', 'Trial3']
#     SOL5 sol5_3 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_3 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_3 Trial3
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_4: ['trial1', 'trial2']
#     SOL5 sol5_4 trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_4 trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_5: ['Trial1', 'Trial2']
#     SOL5 sol5_5 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL5 sol5_5 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_6: ['Trail2']
#     SOL5 sol5_6 Trail2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_7: ['Trail1']
#     SOL5 sol5_7 Trail1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL5 sol5_8: [None]
#     SOL5 sol5_8 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# SOL6: ['sol6_0', 'sol6_1', 'sol6_2', 'sol6_3', 'sol6_4']
#   SOL6 sol6_0: ['Trial1']
#     SOL6 sol6_0 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL6 sol6_1: ['Trial2', 'Trial3_HRC']
#     SOL6 sol6_1 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL6 sol6_1 Trial3_HRC
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL6 sol6_2: ['Trial1', 'Trial2']
#     SOL6 sol6_2 Trial1
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#     SOL6 sol6_2 Trial2
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL6 sol6_3: [None]
#     SOL6 sol6_3 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
#   SOL6 sol6_4: [None]
#     SOL6 sol6_4 None
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# Exporting image using 99th percentile stretch
# Stretching image using 99th percentile stretch
# Exporting image using brightest pixel stretch
# Stretching image using brightest pixel stretch
# TEAM_RGB: []
# sol99_4: []
